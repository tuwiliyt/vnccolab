# %% [markdown]
# # 🖥️ Google Colab Remote Desktop (XFCE + noVNC + Cloudflare Tunnel)
#
# Notebook ini digunakan untuk menjalankan antarmuka grafis (GUI) Remote Desktop langsung di Google Colab dan dapat diakses dari browser mana saja (PC/HP).
#
# ### 📌 Cara Menggunakan:
# 1. Tentukan password VNC pada form di bawah (atau biarkan default: `vncpass123`).
# 2. Klik tombol **Play (Run)** pada cell di bawah.
# 3. Tunggu hingga proses selesai (sekitar 1-2 menit).
# 4. Buka link **Cloudflare (.trycloudflare.com)** yang muncul di output.

# %%
#@title 🚀 Jalankan Remote Desktop
#@markdown Masukkan password yang diinginkan untuk login VNC:
Password = "vncpass123" #@param {type:"string"}

# !curl -sL https://raw.githubusercontent.com/tuwiliyt/vnccolab/main/vnc.sh | bash -s -- "$Password"

# %% [markdown]
# ### 🕒 Tips Agar Colab Tidak Cepat Terputus (Idle Disconnect)
# Biarkan tab Google Colab tetap terbuka di latar belakang saat Anda menggunakan remote desktop.
