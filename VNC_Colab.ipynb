# %% [markdown]
# # 🖥️ Google Colab Remote Desktop (T4 GPU + Google Drive)
#
# Jalankan antarmuka grafis (XFCE4 GUI + noVNC + Cloudflare) di Google Colab.
# - ⚡ **Dukungan GPU T4**: Dapat menjalankan aplikasi CUDA, PyTorch, Rendering, dll.
# - 📁 **Google Drive**: Terhubung langsung dan muncul sebagai folder di Desktop.
# - 🌐 **Akses via Web Browser**: Langsung buka di Chrome/Safari/Edge tanpa instal aplikasi remote.

# %%
#@title 🚀 Jalankan Remote Desktop
#@markdown Centang jika ingin menghubungkan Google Drive ke Desktop:
Hubungkan_Google_Drive = True #@param {type:"boolean"}

#@markdown Masukkan password login VNC:
Password = "vncpass123" #@param {type:"string"}

if Hubungkan_Google_Drive:
    from google.colab import drive
    drive.mount('/content/drive')

# !curl -sL https://raw.githubusercontent.com/tuwiliyt/vnccolab/main/vnc.sh | bash -s -- "$Password"

# %% [markdown]
# ### 💡 Catatan & Tips:
# 1. Pastikan Runtime Colab diatur ke **T4 GPU** melalui menu `Runtime > Change runtime type > T4 GPU`.
# 2. Google Drive Anda akan otomatis muncul sebagai shortcut icon **Google Drive** di Desktop.
# 3. Biarkan tab Colab ini tetap terbuka agar sesi tidak idle/disconnect.
